# %% [markdown]
# ### Comment
#
# * When writing code in Python, it’s important to make sure that your code can be easily understood by others, say by your friend who wants to see your code.
# * Python ignores everything after the hash mark and up to the end of the line. You can insert them anywhere in your code!
# * A shortcut for adding comments is by using CTRL + /

# %%
# assing a value 5 to b
b = 5
print(b)
# Out:
# 5

# %% [markdown]
# ### Operators
# * Operators are used to perform simple operations such as additions, comparisons etc on variables and values.
# * Python supports the following types of operators, we will be looking at some of the commonly used operators.
#
# ![operator.png](attachment:operator.png)

# %% [markdown]
# #### Arithmetic
# ![arith.png](attachment:arith.png)

# %%
#assing a value to x and y
x = 2 
y = 3

# %%
# additin and mutiplication
a = x+y
b = x*y
print(a)
print(b)
# Out:
# 5
# 6

# %%
a = 4**2 #exponentiation
print(a)
# Out:
# 16

# %%
b = 18%7 #modulo
print(b)
# Out:
# 4

# %%
c = x-y-2 #subtraction
print(c)
# Out:
# -3

# %%
d = x/y # Division
print(d)
# Out:
# 0.6666666666666666

# %%
e = x//y #floor division
print(e)
# Out:
# 0

# %% [markdown]
# #### Comparion Operator
# * These are used to compare two values
# * Gives a boolean result: [true/false]
#
# ![comparion.png](attachment:comparion.png)

# %%
#numeric calculation
a = 2 < 3
print(a)
# Out:
# True

# %%
b = 2 == 3
print(b)
# Out:
# False

# %%
c = 2 <= 3
print(c)
# Out:
# True

# %%
#String comparisons
e = "rahul" < "rohan"
print(e)
# Out:
# True

# %% [markdown]
# #### Logical Operators
# * Logical operators are used to combine conditional statements
# * Gives a boolean result: [True/False]
#
# ![logical.png](attachment:logical.png)

# %%
x = 6
a = x < 5  and x < 10
print(a)
# Out:
# False

# %%
b = x < 10 or x < 4
print(b)
# Out:
# True

# %%
c = not(x < 5 and x < 10)
print(c)
# Out:
# True

# %% [markdown]
# Done:)
