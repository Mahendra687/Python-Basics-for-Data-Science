# %% [markdown]
# ### Variables
# * A variable can be considered as a storage container for data.
# * Every variable will have a name.
# * It is a good way to store information while making it easy to refer to that information in our code later.
#
# ![variable.png](attachment:variable.png)
# * For instance, instead of working with the number 3.14, we can assign it to a variable pi and use it as many times as we want in our code (wherever required).
# * The equal sign (=) is used to assign values to variables.
# * The syntax for assigning values to a variable is as follows: Variable name = value or information.

# %% [markdown]
# ### Naming Convention

# %%
from pandas import*

# %%
#Camel
ageEmp = 56
AgeEmp = 54

#snake

age_emp = 45
Age_emp = 50

#Pascal

AgeEmp = 85

# %% [markdown]
# ### Assigning_Values

# %%
Biochem, Genetics, Immunology, Bioinformatics = 10,20,30,40
print(Biochem, Bioinformatics,Genetics, Immunology)
# Out:
# 10 40 20 30

# %% [markdown]
# ### Data type

# %%
Name = "Mahendra"
Age = 28
Weight = 70.5
print(Name)
print(Age)
print(Weight)
# Out:
# Mahendra
# 28
# 70.5

# %% [markdown]
# ### Identifying the Data types

# %%
type(Name)
# Out:
# str

# %%
type(Age)
# Out:
# int

# %%
type(Weight)
# Out:
# float

# %%
type(Name) is str
# Out:
# True

# %%
type(Age) is int
# Out:
# True

# %%
type(Weight) is float
# Out:
# True

# %%
type(Age) is float
# Out:
# False

# %% [markdown]
# ### Data Types Conversion

# %%
type(Age)
# Out:
# int

# %%
Fl_Int = float(Age)

# %%
type(Fl_Int)
# Out:
# float

# %%
Int_Flt = int(Weight)
type(Int_Flt)
# Out:
# int

# %%
Salary_tier = "1"
Int_str = int(Salary_tier)
type(Int_str)
# Out:
# int

# %% [markdown]
# #### Print Function
# * print is the built in fucction that instructs system to print something that is inside the parenthesis (" ")

# %%
#example:
print("boy with love by BTS")
# Out:
# boy with love by BTS

# %% [markdown]
# #### Input Function
# * similar to print function

# %%
#example
x = input("Please enter your age: ")
print("your age is:"+ x )
# Out:
# Please enter your age: 25
# your age is:25

# %%
type(x)
# Out:
# str

# %% [markdown]
# Done:)
